# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\GitHub\glovo-spec-analysis\data\glovo_reviews_raw.csv")

# %%
df.head()
# Out:
#                               review_id             user  rating  \
# 0  9545b388-0a2f-4f5e-a001-f50f392b7b11      Joel Ibanga       5
# 1  7e5e2547-f5df-4cf5-be4f-7c4ba7995810     joy olayinka       4
# 2  5a8e3559-772a-41f0-b172-1e7743579b52  Emmanuel Otukol       5
# 3  b34e020e-d85b-4b97-921e-4efe5c30ea2b     Tudor Radutu       1
# 4  63b022d9-b5d2-4222-b060-cf53beb95d85    Colines Okelo       5
#
#                   date                                               text  \
# 0  2026-08-07 14:38:55                                          very fast
# 1  2026-08-07 12:52:18                                       satisfactory
# 2  2026-08-07 11:28:28                                               Cool
# 3  2026-08-07 10:55:44  worst service ever, overpriced delivery fees, ...
# 4  2026-08-07 10:29:49                                               cool
#
#    thumbs_up
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.columns
# Out:
# Index(['review_id', 'user', 'rating', 'date', 'text', 'thumbs_up'], dtype='object')

# %%
df['review_lower'] = df['text'].str.lower()

# %%
df['review_lower']
# Out:
# 0                                              very fast
# 1                                           satisfactory
# 2                                                   cool
# 3      worst service ever, overpriced delivery fees, ...
# 4                                                   cool
#                              ...
# 595                                            very good
# 596                                             nice one
# 597                 expand your delivery location reach.
# 598    why would meals cost extra if i'm already payi...
# 599    scamers, they say we will refund, and then the...
# Name: review_lower, Length: 600, dtype: object

# %%
df['is_payment'] = df['review_lower'].str.contains('refund|refunded|charge|charged|debit|debitted|money|bank|card|compensation|scam|scammed|stole|stolen|credit')

# %%
df['is_payment'].value_counts()
# Out:
# is_payment
# False    527
# True      73
# Name: count, dtype: int64

# %%
df[df['is_payment'] == True]['rating'].mean()
# Out:
# 1.3424657534246576

# %%
df[df['is_payment'] == False]['rating'].mean()
# Out:
# 3.81404174573055

# %%
df['is_order_accuracy'] = df['review_lower'].str.contains('wrong|missing|didn\'t arrive|never arrived|not delivered|swapped|incomplete')

# %%
df[df['is_order_accuracy'] == True]['rating'].mean()
# Out:
# 1.411764705882353

# %%
df[df['is_order_accuracy'] == False]['rating'].mean()
# Out:
# 3.574614065180103

# %%
df['is_delivery_time'] = df['review_lower'].str.contains('late|slow|delay|delayed|waiting|hours|wait')

# %%
df[df['is_delivery_time'] == True]['rating'].mean()
# Out:
# 1.5

# %%
df[df['is_delivery_time'] == False]['rating'].mean()
# Out:
# 3.619298245614035

# %%
df['is_support'] = df['review_lower'].str.contains('support|customer service|customer care|agent|chat|unhelpful|no response|ignored')

# %%
df[df['is_support'] == True]['rating'].mean()
# Out:
# 1.7755102040816326

# %%
df[df['is_support'] == False]['rating'].mean()
# Out:
# 3.6678765880217785

# %%
df['is_order_accuracy'].value_counts()
# Out:
# is_order_accuracy
# False    583
# True      17
# Name: count, dtype: int64

# %%
df['is_delivery_time'].value_counts()
# Out:
# is_delivery_time
# False    570
# True      30
# Name: count, dtype: int64

# %%
df['is_support'].value_counts()
# Out:
# is_support
# False    551
# True      49
# Name: count, dtype: int64

# %%
df[df['is_order_accuracy'] == False]['text']. sample(40)
# Out:
# 406                                                 good
# 373                                         very good 💯😊
# 233    Glovo food and Groceries are very fresh yummy ...
# 13                                             excellent
# 245    2026 retarded UX. Cannot go to store from orde...
# 213    Fast delivery with easy and mouth watery Dodo ...
# 166                            the app is not responding
# 117    Cancelling the subscription and deinstaling ap...
# 280                                   excellent services
# 342                                        good delivery
# 251                                           your the 👌
# 558    daca aplicația asta ar avea metoda de pick up ...
# 522    Reliability and discipline (time management) d...
# 11     Great for a lazy day, the order can be brought...
# 467                          horrible 1 star is too much
# 530    Dont use this app for any ordering. All the di...
# 355                               Great service delivery
# 479                    quick deliveries and nice items 👌
# 299    Is this the new way of BEGGING or SCAMMING peo...
# 545                                         Poor service
# 217                      the best app for swift delivery
# 140                                                   ok
# 97                                     belle application
# 252    ⭐☆☆☆☆ ⚠️ À tous ceux qui pensent utiliser Glov...
# 367    constant errors, crashes and can't process pay...
# 263                                                 nice
# 511                               too long to get a meal
# 541           The app is great but the support is trash.
# 378                                             حاو فنان
# 129                                                 Good
# 431                               delivery was very fast
# 399       fast to get food delivered to your doorstep...
# 289                                          excellent 👍
# 255    ywasel ken fl 3asma wjerba w Sousse yaany ken ...
# 592                        Very reliable and convenient.
# 444                                             Soo fast
# 101                               price isnso over-rated
# 578                             pick up option is broken
# 99     very bed system. I ordered my food from glove ...
# 385    the rider has being with my food for 1hr plus ...
# Name: text, dtype: object

# %%
categories = ['Payment/Refund', 'Order Accuracy', 'Delivery time', 'Support']
avg_rating = [1.34, 1.41, 1.50, 1.78]
counts = [73, 17, 30, 49]

# %%
plt.bar(categories, avg_rating)
plt.show()

# %%
plt.bar(categories, counts)
plt.show()
